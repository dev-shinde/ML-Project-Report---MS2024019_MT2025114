# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder, StandardScaler
from xgboost import XGBClassifier

# Load the training and test data
train = pd.read_csv("train.csv")
test  = pd.read_csv("test.csv")

# =============================================
# Separate features and target
# =============================================
X_train = train.drop(['id', 'WeightCategory'], axis=1)
y_train = train['WeightCategory']

X_test = test.drop(['id'], axis=1)  # Only features, no target

# One-hot encode categorical features
X_train = pd.get_dummies(X_train, drop_first=True)
X_test  = pd.get_dummies(X_test,  drop_first=True)

# Align columns
X_test = X_test.reindex(columns = X_train.columns, fill_value=0)

# Scale numeric features
scaler = StandardScaler()
X_train_s = scaler.fit_transform(X_train)
X_test_s  = scaler.transform(X_test)

# Encode target
le = LabelEncoder()
y_train_enc = le.fit_transform(y_train)

# Base model
xgb = XGBClassifier(
    objective='multi:softprob',
    eval_metric='mlogloss',
    use_label_encoder=False,
    random_state=42,
    n_jobs=-1,
    tree_method='hist'
)

# Focused Grid Search Space based on your top performers
param_grid = {
    'n_estimators':  [345,355],
    'learning_rate': np.linspace(0.15, 0.2, 7),
    'max_depth': [3],
    'min_child_weight': [4.5, 5],
    'subsample': [0.8],
    'colsample_bytree': [0.6],
    'gamma': [ 0.45, 0.55],
    'reg_alpha': [0.7, 0.75],
    'reg_lambda': [ 2.95, 3.15],
}
print(f"Total combinations: {np.prod([len(v) for v in param_grid.values()])}")

# Grid search
grid_search = GridSearchCV(
    estimator=xgb,
    param_grid=param_grid,
    scoring='accuracy',
    cv=5,
    verbose=1,
    n_jobs=-1,
    return_train_score=False
)

grid_search.fit(X_train_s, y_train_enc)

print("✅ Best parameters:", grid_search.best_params_)
print("✅ Best CV Accuracy:", grid_search.best_score_ * 100)

# ====== Extract top 10 parameter sets ======
import pandas as pd
results_df = pd.DataFrame(grid_search.cv_results_)
# First filter for accuracy in range 90.83 to 90.87
filtered_results = results_df[
    (results_df['mean_test_score'] >= 0.9081) & 
    (results_df['mean_test_score'] < 0.9087)
]

# Sort by mean_test_score descending and take top 10
top10 = filtered_results.sort_values('mean_test_score', ascending=False).head(10)

print(f"\nTop 10 parameter sets:")
for idx, (_, row) in enumerate(top10.iterrows(), 1):
    print(f"{idx}: {row['mean_test_score']:.4f} => params={row['params']}")

# ====== Loop through top 10 and train/predict & save CSVs ======
for i, (_, row) in enumerate(top10.iterrows(), 1):
    params_i = row['params']
    print(f"\nTraining model #{i} with score {row['mean_test_score']:.4f}")
    print(f"Params: {params_i}")
    
    model_i = XGBClassifier(
        objective='multi:softprob',
        eval_metric='mlogloss',
        use_label_encoder=False,
        random_state=42,
        n_jobs=-1,
        tree_method='hist',
        **params_i
    )
    
    # Train on full training data
    model_i.fit(X_train_s, y_train_enc)
    
    # Predict on test data
    y_pred_i = model_i.predict(X_test_s)
    y_pred_labels_i = le.inverse_transform(y_pred_i)
    
    # Create submission file
    submission_i = pd.DataFrame({'id': test['id'], 'WeightCategory': y_pred_labels_i})
    filename = f"model{i}_score_{row['mean_test_score']:.4f}.csv"
    submission_i.to_csv(filename, index=False)
    print(f"✅ Saved {filename}")

print(f"\nAll done. Generated 10 submission files: submission_top10_model1.csv … submission_top10_model10.csv")
# Out:
# Total combinations: 224
# Fitting 5 folds for each of 224 candidates, totalling 1120 fits
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:00] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:00] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:00] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:01] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:01] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:01] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:01] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:01] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:06] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:06] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:06] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:06] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:06] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:07] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:07] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:07] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:11] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:12] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:12] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:12] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:12] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:12] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:12] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:12] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:18] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:18] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:18] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:19] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:19] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:19] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:19] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:20] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:25] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:25] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:26] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:26] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:26] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:26] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:26] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:27] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:32] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:32] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:32] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:32] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:33] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:34] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:34] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:34] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:39] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:39] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:39] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:39] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:39] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:40] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:41] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:42] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:46] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:46] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:46] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:46] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:46] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:47] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:48] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:48] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:52] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:53] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:53] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:53] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:53] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:54] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:54] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:55] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:00:58] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:00] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:00] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:00] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:01] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:01] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:01] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:01] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:05] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:07] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:07] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:07] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:08] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:08] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:08] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:08] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:12] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:13] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:14] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:14] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:14] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:15] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:15] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:15] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:19] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:20] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:20] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:21] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:21] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:21] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:22] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:24] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:25] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:27] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:27] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:27] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:28] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:28] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:28] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:31] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:32] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:33] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:34] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:34] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:35] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:35] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:36] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:38] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:39] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:40] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:41] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:41] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:42] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:42] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:42] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:45] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:46] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:46] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:48] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:48] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:48] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:49] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:49] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:52] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:52] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:53] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:54] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:55] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:56] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:56] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:56] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:59] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:01:59] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:02:00] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:02:01] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:02:02] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:02:02] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:02:02] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:02:05] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:02:06] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:02:06] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:02:07] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:02:07] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:02:09] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:02:09] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:02:09] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:02:12] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:02:13] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:02:13] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:02:13] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:02:14] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:02:15] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ...
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:16:48] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:16:48] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:16:50] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:16:51] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:16:51] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:16:52] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:16:54] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:16:54] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:16:55] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:16:55] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:16:57] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:16:57] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:16:58] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:16:58] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:17:02] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:17:02] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:17:02] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:17:02] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:17:04] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:17:05] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:17:06] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:17:09] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:17:09] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:17:09] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:17:10] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:17:15] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ✅ Best parameters: {'colsample_bytree': 0.6, 'gamma': 0.55, 'learning_rate': np.float64(0.19166666666666668), 'max_depth': 3, 'min_child_weight': 4.5, 'n_estimators': 355, 'reg_alpha': 0.7, 'reg_lambda': 3.15, 'subsample': 0.8}
# ✅ Best CV Accuracy: 90.85179779120782
#
# Top 10 parameter sets:
# 1: 0.9085 => params={'colsample_bytree': 0.6, 'gamma': 0.55, 'learning_rate': np.float64(0.19166666666666668), 'max_depth': 3, 'min_child_weight': 4.5, 'n_estimators': 355, 'reg_alpha': 0.7, 'reg_lambda': 3.15, 'subsample': 0.8}
# 2: 0.9084 => params={'colsample_bytree': 0.6, 'gamma': 0.45, 'learning_rate': np.float64(0.18333333333333335), 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 345, 'reg_alpha': 0.75, 'reg_lambda': 2.95, 'subsample': 0.8}
# 3: 0.9083 => params={'colsample_bytree': 0.6, 'gamma': 0.55, 'learning_rate': np.float64(0.19166666666666668), 'max_depth': 3, 'min_child_weight': 4.5, 'n_estimators': 355, 'reg_alpha': 0.7, 'reg_lambda': 2.95, 'subsample': 0.8}
# 4: 0.9083 => params={'colsample_bytree': 0.6, 'gamma': 0.55, 'learning_rate': np.float64(0.15833333333333333), 'max_depth': 3, 'min_child_weight': 4.5, 'n_estimators': 355, 'reg_alpha': 0.75, 'reg_lambda': 3.15, 'subsample': 0.8}
# 5: 0.9083 => params={'colsample_bytree': 0.6, 'gamma': 0.45, 'learning_rate': np.float64(0.175), 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 345, 'reg_alpha': 0.7, 'reg_lambda': 2.95, 'subsample': 0.8}
# 6: 0.9083 => params={'colsample_bytree': 0.6, 'gamma': 0.55, 'learning_rate': np.float64(0.19166666666666668), 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 355, 'reg_alpha': 0.7, 'reg_lambda': 3.15, 'subsample': 0.8}
# 7: 0.9082 => params={'colsample_bytree': 0.6, 'gamma': 0.55, 'learning_rate': np.float64(0.18333333333333335), 'max_depth': 3, 'min_child_weight': 4.5, 'n_estimators': 345, 'reg_alpha': 0.7, 'reg_lambda': 3.15, 'subsample': 0.8}
# 8: 0.9082 => params={'colsample_bytree': 0.6, 'gamma': 0.55, 'learning_rate': np.float64(0.18333333333333335), 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 355, 'reg_alpha': 0.75, 'reg_lambda': 3.15, 'subsample': 0.8}
# 9: 0.9082 => params={'colsample_bytree': 0.6, 'gamma': 0.55, 'learning_rate': np.float64(0.19166666666666668), 'max_depth': 3, 'min_child_weight': 4.5, 'n_estimators': 355, 'reg_alpha': 0.75, 'reg_lambda': 2.95, 'subsample': 0.8}
# 10: 0.9082 => params={'colsample_bytree': 0.6, 'gamma': 0.45, 'learning_rate': np.float64(0.175), 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 355, 'reg_alpha': 0.7, 'reg_lambda': 2.95, 'subsample': 0.8}
#
# Training model #1 with score 0.9085
# Params: {'colsample_bytree': 0.6, 'gamma': 0.55, 'learning_rate': np.float64(0.19166666666666668), 'max_depth': 3, 'min_child_weight': 4.5, 'n_estimators': 355, 'reg_alpha': 0.7, 'reg_lambda': 3.15, 'subsample': 0.8}
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:17:19] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ✅ Saved model1_score_0.9085.csv
#
# Training model #2 with score 0.9084
# Params: {'colsample_bytree': 0.6, 'gamma': 0.45, 'learning_rate': np.float64(0.18333333333333335), 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 345, 'reg_alpha': 0.75, 'reg_lambda': 2.95, 'subsample': 0.8}
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:17:21] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ✅ Saved model2_score_0.9084.csv
#
# Training model #3 with score 0.9083
# Params: {'colsample_bytree': 0.6, 'gamma': 0.55, 'learning_rate': np.float64(0.19166666666666668), 'max_depth': 3, 'min_child_weight': 4.5, 'n_estimators': 355, 'reg_alpha': 0.7, 'reg_lambda': 2.95, 'subsample': 0.8}
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:17:23] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ✅ Saved model3_score_0.9083.csv
#
# Training model #4 with score 0.9083
# Params: {'colsample_bytree': 0.6, 'gamma': 0.55, 'learning_rate': np.float64(0.15833333333333333), 'max_depth': 3, 'min_child_weight': 4.5, 'n_estimators': 355, 'reg_alpha': 0.75, 'reg_lambda': 3.15, 'subsample': 0.8}
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:17:26] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ✅ Saved model4_score_0.9083.csv
#
# Training model #5 with score 0.9083
# Params: {'colsample_bytree': 0.6, 'gamma': 0.45, 'learning_rate': np.float64(0.175), 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 345, 'reg_alpha': 0.7, 'reg_lambda': 2.95, 'subsample': 0.8}
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:17:28] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ✅ Saved model5_score_0.9083.csv
#
# Training model #6 with score 0.9083
# Params: {'colsample_bytree': 0.6, 'gamma': 0.55, 'learning_rate': np.float64(0.19166666666666668), 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 355, 'reg_alpha': 0.7, 'reg_lambda': 3.15, 'subsample': 0.8}
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:17:29] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ✅ Saved model6_score_0.9083.csv
#
# Training model #7 with score 0.9082
# Params: {'colsample_bytree': 0.6, 'gamma': 0.55, 'learning_rate': np.float64(0.18333333333333335), 'max_depth': 3, 'min_child_weight': 4.5, 'n_estimators': 345, 'reg_alpha': 0.7, 'reg_lambda': 3.15, 'subsample': 0.8}
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:17:33] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ✅ Saved model7_score_0.9082.csv
#
# Training model #8 with score 0.9082
# Params: {'colsample_bytree': 0.6, 'gamma': 0.55, 'learning_rate': np.float64(0.18333333333333335), 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 355, 'reg_alpha': 0.75, 'reg_lambda': 3.15, 'subsample': 0.8}
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:17:35] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ✅ Saved model8_score_0.9082.csv
#
# Training model #9 with score 0.9082
# Params: {'colsample_bytree': 0.6, 'gamma': 0.55, 'learning_rate': np.float64(0.19166666666666668), 'max_depth': 3, 'min_child_weight': 4.5, 'n_estimators': 355, 'reg_alpha': 0.75, 'reg_lambda': 2.95, 'subsample': 0.8}
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:17:36] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ✅ Saved model9_score_0.9082.csv
#
# Training model #10 with score 0.9082
# Params: {'colsample_bytree': 0.6, 'gamma': 0.45, 'learning_rate': np.float64(0.175), 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 355, 'reg_alpha': 0.7, 'reg_lambda': 2.95, 'subsample': 0.8}
# /home/shikhar/Sem 1/ML Project/100 Days Of ML/Original ML Project Data/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [23:17:41] WARNING: /workspace/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ✅ Saved model10_score_0.9082.csv
#
# All done. Generated 10 submission files: submission_top10_model1.csv … submission_top10_model10.csv
